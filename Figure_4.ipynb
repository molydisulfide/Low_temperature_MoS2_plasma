# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
import csv
import matplotlib.patches as mpatches
import pylab as pb
import matplotlib.ticker as mtick
from matplotlib import cm
from numpy import linspace
from csv import reader
from matplotlib import pyplot
import matplotlib.colors as colors
import bokeh as bk
import seaborn as sns
import pandas as pd

# %%
time_bar = []
highT_bar = []
lowT_bar = []
with open('barriers.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        time_bar.append(float(row[0]))
        highT_bar.append(float(row[1]))
        lowT_bar.append(float(row[2]))

# %%
temp = []
s_0s = []
xfit_0s = []
yfit_0s  = []
s_4s = []
xfit_4s = []
yfit_4s  = []
s_6s = []
xfit_6s = []
yfit_6s  = []
s_8s = []
xfit_8s = []
yfit_8s  = []
xfit_neg4s = []
yfit_neg4s  = []
xfit_neg6s = []
yfit_neg6s  = []
xfit_neg8s = []
yfit_neg8s  = []
with open('schottky.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        temp.append(float(row[0]))
        s_0s.append(float(row[1]))
        xfit_0s.append(float(row[5]))
        yfit_0s.append(float(row[6]))
        s_4s.append(float(row[2]))
        xfit_4s.append(float(row[7]))
        yfit_4s.append(float(row[8]))
        s_6s.append(float(row[3]))
        xfit_6s.append(float(row[9]))
        yfit_6s.append(float(row[10]))
        s_8s.append(float(row[4]))
        xfit_8s.append(float(row[11]))
        yfit_8s.append(float(row[12]))
        xfit_neg4s.append(float(row[13]))
        yfit_neg4s.append(float(row[14]))
        xfit_neg6s.append(float(row[15]))
        yfit_neg6s.append(float(row[16]))
        xfit_neg8s.append(float(row[17]))
        yfit_neg8s.append(float(row[18]))

# %%
fig = plt.figure(figsize=(8,8))
fig.canvas.draw()

sns.set_style('ticks')

 




ax1 = fig.add_subplot(221)
ax1.plot(temp,s_0s, '-o', ms=10, color = 'black', ls = 'None',lw=2, alpha=0.7, mfc='black', dash_capstyle = 'butt', mew = '1', label = '0 sec'  )
ax1.plot(xfit_0s,yfit_0s, '-', ms=10, color = 'black', lw=2, alpha=0.7, mfc='black', dash_capstyle = 'butt', mew = '1' ) 
ax1.set_title('0 seconds')
#plt.xscale('log')

ax2 = fig.add_subplot(222)
ax2.plot(temp,s_4s, '-^', ms=10, color = 'r', ls = 'None', lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '4 sec' ) 
ax2.plot(xfit_4s,yfit_4s, '-', ms=10, color = 'r',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1') 
ax2.plot(xfit_neg4s,yfit_neg4s, '-', ms=10, color = 'r', lw=2, alpha=0.7, mfc='black', dash_capstyle = 'butt', mew = '1' ) 
ax2.set_title('4 seconds')#
#plt.xscale('log')

ax3 = fig.add_subplot(223)
ax3.plot(temp,s_6s, '-s', ms=10, color = 'g', ls = 'None', lw=2, alpha=0.7, mfc='g', dash_capstyle = 'butt', mew = '1', 
              label = '6 sec' ) 
ax3.plot(xfit_6s,yfit_6s, '-', ms=10, color = 'g',  lw=2, alpha=0.7, mfc='g', dash_capstyle = 'butt', mew = '1' ) 
ax3.plot(xfit_neg6s,yfit_neg6s, '-', ms=10, color = 'g',  lw=2, alpha=0.7, mfc='g', dash_capstyle = 'butt', mew = '1' ) 
ax3.set_title('6 seconds')
#plt.xscale('log')

ax4 = fig.add_subplot(224)
ax4.plot(temp,s_8s, '-d', ms=10, color = 'b', ls = 'None', lw=2, alpha=0.7, mfc='b', dash_capstyle = 'butt', mew = '1', 
              label = '8 sec' ) 
ax4.plot(xfit_neg8s,yfit_neg8s, '-', ms=10, color = 'b',  lw=2, alpha=0.7, mfc='g', dash_capstyle = 'butt', mew = '1' ) 
ax4.plot(xfit_8s,yfit_8s, '-', ms=10, color = 'b',  lw=2, alpha=0.7, mfc='b', dash_capstyle = 'butt', mew = '1' ) 
ax4.set_title('8 seconds')
#plt.xscale('log')
ax1.set_ylabel('ln(I/T$^{3/2}$)', fontsize = 13.5)
ax3.set_xlabel('T$^{-1}$ (K$^{-1}$)', fontsize = 13.5)
ax3.set_ylabel('ln(I/T$^{3/2}$)', fontsize = 13.5)
ax4.set_xlabel('T$^{-1}$ (K$^{-1}$)', fontsize = 13.5)


plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=True)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=True)
plt.setp(ax4.get_yticklabels(), visible=True)
plt.setp(ax4.get_xticklabels(), visible=True)

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax4.xaxis.set_ticks_position('bottom')
ax4.yaxis.set_ticks_position('left')



#ax1.set_ylim([0.0000000001,0.00001])
#ax2.set_ylim([0.0000000001,0.00001])
#ax3.set_ylim([0.000000005,0.00001])
#ax4.set_ylim([0.0000000001,0.0001])
#ax1.set_xlim([0.003,0.014])
#ax2.set_xlim([0.003,0.014])
#ax3.set_xlim([0.003,0.014])
#ax4.set_xlim([0.003,0.014])

#major_ticks_1 = np.arange(0.004, 0.012, 0.002)   
#ax4.set_xticks(major_ticks_1) 
#ax2.set_xticks(major_ticks_1)
#ax1.legend(loc = 'upper right', ncol = 1, fontsize=12)
#ax2.legend(loc = 'upper right', ncol = 1, fontsize=12)
#ax3.legend(loc = 'upper right', ncol = 1, fontsize=12)
#ax4.legend(loc = 'upper right', ncol = 1, fontsize=12)
plt.savefig("Fig_4_tot.png",bbox_inches='tight', dpi = 300)


plt.show()

# %%
fig = plt.figure(figsize=(4,4))
fig.canvas.draw()

sns.set_style('ticks')

ax1 = fig.add_subplot(111)
ax1.plot(time_bar,highT_bar, '--o', ms=10, color = 'orange',lw=2, alpha=0.7, mfc='orange', dash_capstyle = 'butt', mew = '1', label = '0 sec'  )
ax1.plot(time_bar,lowT_bar, '--s', ms=10, color = 'blue', lw=2, alpha=0.7, mfc='blue', dash_capstyle = 'butt', mew = '1' ) 
ax1.set_title('$\phi_{B}(t)$ at different temperatures')

ax1.set_ylabel('$\phi_{B}$ (meV)', fontsize = 13.5)
ax1.set_xlabel('Exposure time (s)', fontsize = 13.5)

#ax1.set_ylim([0.0000000001,0.00001])
ax1.set_xlim([-1,9])
ax1.axhspan(0, 30, color='orange', alpha=0.1)
ax1.axhspan(0, -30, color='b', alpha=0.1)
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')

plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax1.get_yticklabels(), visible=False)
plt.savefig("barriers.png",bbox_inches='tight', dpi = 300)


plt.show()

# %%
fig = plt.figure(figsize=(5,5))



opened_file = open("all_I_4s.txt")
csv_data = csv.reader(opened_file, delimiter="\t")
parsed_data = []

for row in csv_data:
    parsed_data.append(row)
opened_file.close()

data = np.array(parsed_data)
#new_data = data[::8]
ax=plt.gca()
colormap = plt.get_cmap('RdBu')
ax.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 40)])
#ax.axvspan(5.5, 6.5, color='orange', alpha=0.5)
for i in range(1,112):
        if i % 3 == 0:
            plt.plot(data[0:17,0],data[0:17,i], '-o',lw = '0.8')
            axes = plt.gca()
            
#axes.set_xlim([0,10])
#axes.set_ylim([0,125])
axes.set_xlabel('1/T (1/K)', fontsize = 25)
axes.set_ylabel('ln(I/T$^{3/2}$)', fontsize = 25)
plt.yticks(fontsize = 15)
plt.xticks(fontsize = 15)
plt.tight_layout()
plt.savefig("4s_schottky_60to0gate.png", dpi=300)
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-214-ea943cd20be5> in <module>()
#      17 ax.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 40)])
#      18 #ax.axvspan(5.5, 6.5, color='orange', alpha=0.5)
# ---> 19 for i in range(1,112):
#      20         if i % 3 == 0:
#      21             plt.plot(data[0:17,0],data[0:17,i], '-o',lw = '0.8')
#
# TypeError: 'list' object is not callable

# %%
fig = plt.figure(figsize=(5,5))
#min, max = (-60, 60)
#step = 0.5
#mymap = mpl.colors.LinearSegmentedColormap.from_list('mycolors',['blue','red'])
#Z = [[0,0],[0,0]]
#levels = range(min,max+step,step)

#CS3 = plt.contourf(Z, levels, cmap='viridis', fontsize = 40)

#plt.clf()  
  
#plt.colorbar(CS3) # using the colorbar info I got from contourf 


opened_file = open("all_I_4s.txt")
csv_data = csv.reader(opened_file, delimiter="\t")
parsed_data = []

for row in csv_data:
    parsed_data.append(row)
opened_file.close()

data = np.array(parsed_data)
#new_data = data[::8]
ax=plt.gca()
colormap = plt.get_cmap('winter')
ax.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 40)])
#ax.axvspan(5.5, 6.5, color='orange', alpha=0.5)
for i in range(122,224):
        if i % 3 == 0:
            plt.plot(data[0:17,0],data[0:17,i], lw = 2)
            axes = plt.gca()
#axes.set_xlim([0,10])
#axes.set_ylim([0,125])
axes.set_xlabel('1/T (1/K)', fontsize = 25)
axes.set_ylabel('ln(I/T$^{3/2}$)', fontsize = 25)
plt.yticks(fontsize = 15)
plt.xticks(fontsize = 15)
plt.tight_layout()
plt.savefig("4s_schottky_0toneg60gate.png", dpi=300)

# %%
fig = plt.figure(figsize=(5,5))



opened_file = open("all_I_0s.txt")
csv_data = csv.reader(opened_file, delimiter="\t")
parsed_data = []

for row in csv_data:
    parsed_data.append(row)
opened_file.close()

data = np.array(parsed_data)
#new_data = data[::8]
ax=plt.gca()
colormap = plt.get_cmap('RdBu')
ax.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 40)])
#ax.axvspan(5.5, 6.5, color='orange', alpha=0.5)
for i in range(1,112):
        if i % 3 == 0:
            plt.plot(data[0:17,0],data[0:17,i], '-o',lw = '0.8')
            axes = plt.gca()
            
#axes.set_xlim([0,10])
#axes.set_ylim([0,125])
axes.set_xlabel('1/T (1/K)', fontsize = 25)
axes.set_ylabel('ln(I/T$^{3/2}$)', fontsize = 25)
plt.yticks(fontsize = 15)
plt.xticks(fontsize = 15)
plt.tight_layout()
plt.savefig("0s_schottky_60to0gate.png", dpi=300)

# %%
tempo = []
lnI_0s_60Vg = []
lnI_0s_50Vg = []
lnI_0s_40Vg = []
lnI_0s_30Vg = []
lnI_0s_20Vg = []
lnI_0s_10Vg = []
lnI_0s_0Vg = []
lnI_0s_neg10Vg = []
lnI_0s_neg20Vg = []
lnI_0s_neg30Vg = []
lnI_0s_neg40Vg = []
lnI_0s_neg50Vg = []
lnI_0s_neg60Vg = []


with open('all_I_0s.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
            tempo.append(float(row[0]))
            lnI_0s_60Vg.append(float(row[1]))
            lnI_0s_50Vg.append(float(row[20]))
            lnI_0s_40Vg.append(float(row[40]))
            lnI_0s_30Vg.append(float(row[60]))
            lnI_0s_20Vg.append(float(row[80]))
            lnI_0s_10Vg.append(float(row[100]))
            lnI_0s_0Vg.append(float(row[120]))
            lnI_0s_neg10Vg.append(float(row[140]))
            lnI_0s_neg20Vg.append(float(row[160]))
            lnI_0s_neg30Vg.append(float(row[180]))
            lnI_0s_neg40Vg.append(float(row[200]))
            lnI_0s_neg50Vg.append(float(row[220]))
            lnI_0s_neg60Vg.append(float(row[240]))

# %%
tempo4 = []
lnI_4s_60Vg = []
lnI_4s_50Vg = []
lnI_4s_40Vg = []
lnI_4s_30Vg = []
lnI_4s_20Vg = []
lnI_4s_10Vg = []
lnI_4s_0Vg = []
lnI_4s_neg10Vg = []
lnI_4s_neg20Vg = []
lnI_4s_neg30Vg = []
lnI_4s_neg40Vg = []
lnI_4s_neg50Vg = []
lnI_4s_neg60Vg = []


with open('all_I_4s.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
            tempo4.append(float(row[0]))
            lnI_4s_60Vg.append(float(row[1]))
            lnI_4s_50Vg.append(float(row[20]))
            lnI_4s_40Vg.append(float(row[40]))
            lnI_4s_30Vg.append(float(row[60]))
            lnI_4s_20Vg.append(float(row[80]))
            lnI_4s_10Vg.append(float(row[100]))
            lnI_4s_0Vg.append(float(row[120]))
            lnI_4s_neg10Vg.append(float(row[140]))
            lnI_4s_neg20Vg.append(float(row[160]))
            lnI_4s_neg30Vg.append(float(row[180]))
            lnI_4s_neg40Vg.append(float(row[200]))
            lnI_4s_neg50Vg.append(float(row[220]))
            lnI_4s_neg60Vg.append(float(row[240]))

# %%
from __future__ import division
from scipy.stats import *
from scipy.interpolate import *

k = 1.38*10**-23
q = 1.6*10**-19
kq = k/q
vg0s = linspace(60, -60, 13)
vg0s_proper = linspace(60,-60,7)
vg = np.asarray(vg0s)



sbh = [lnI_0s_60Vg,lnI_0s_50Vg,lnI_0s_40Vg,lnI_0s_30Vg,lnI_0s_20Vg,lnI_0s_10Vg,
       lnI_0s_0Vg,lnI_0s_neg10Vg,lnI_0s_neg20Vg,lnI_0s_neg30Vg,lnI_0s_neg40Vg,lnI_0s_neg50Vg,lnI_0s_neg60Vg]

sbh_2 = [lnI_0s_60Vg,lnI_0s_40Vg,lnI_0s_20Vg,
       lnI_0s_0Vg,lnI_0s_neg20Vg,lnI_0s_neg40Vg,lnI_0s_neg60Vg]
                
#for i in sbh_2:
     #slope, intercept, r_value, p_value, std_err = linregress(tempo[0:10], i[0:10])
     #print(slope, intercept, pow(r_value,2))
    
#for i in sbh_2:
    #slope, intercept, r_value, p_value, std_err = linregress(tempo[10:15], i[10:15])
   # print(slope, intercept, pow(r_value,2))
    

sbh_values_2 = [148.4, 126.4,97.4, 48.5, -266.9, 198.1, 196.3]
sbh_values_1 = [424.9,366.1, 244.1,-129.6, -1482.6, -651.7, 352.9]
sbh_proper_2 = [x*kq for x in sbh_values_2]
sbh_proper_1 = [x*kq for x in sbh_values_1]

####################################### 4s data

sbh4 = [lnI_4s_60Vg,lnI_4s_50Vg,lnI_4s_40Vg,lnI_4s_30Vg,lnI_4s_20Vg,lnI_4s_10Vg,
       lnI_4s_0Vg,lnI_4s_neg10Vg,lnI_4s_neg20Vg,lnI_4s_neg30Vg,lnI_4s_neg40Vg,lnI_4s_neg50Vg,lnI_4s_neg60Vg]

sbh4_2 = [lnI_4s_60Vg,lnI_4s_40Vg,lnI_4s_20Vg,
       lnI_4s_0Vg,lnI_4s_neg20Vg,lnI_4s_neg40Vg,lnI_4s_neg60Vg]
                
#for i in sbh4_2:
    #slope, intercept, r_value, p_value, std_err = linregress(tempo4[0:10], i[0:10])
    #print(slope, intercept, pow(r_value,2))
    
#for i in sbh4_2:
    #slope, intercept, r_value, p_value, std_err = linregress(tempo4[10:15], i[10:15])
    #print(slope, intercept, pow(r_value,2))
    

sbh4_values_2 = [177.3,280.8,422.5,388.1,133.1,327,403.1]
sbh4_values_1 = [-194.3,-303.5,-494.8,-240.9,199.6,209.3,217.2]
sbh4_proper_2 = [x*kq for x in sbh4_values_2]
sbh4_proper_1 = [x*kq for x in sbh4_values_1]

print(sbh4_proper_2)
# Out:
# [0.015292124999999998, 0.024218999999999997, 0.03644062499999999, 0.03347362499999999, 0.011479874999999997, 0.028203749999999993, 0.034767374999999996]

# %%
len(sbh4_2)
# Out:
# 7

# %%
fig = plt.figure(figsize=(6,6))
fig.canvas.draw()
sns.set_style('ticks')

mymap = mpl.colors.LinearSegmentedColormap.from_list('mycolors',['blue','red'])
sm = plt.cm.ScalarMappable(cmap=mymap, norm=plt.Normalize(vmin=-60, vmax=60))

sm._A = []
plt.clf()  
cbaxes = fig.add_axes([0.3, 1.051, 0.5, 0.025]) 

plt.colorbar(sm, cax = cbaxes, orientation ='horizontal') 

ax1 = fig.add_subplot(221)
colormap = plt.get_cmap('RdBu')
ax1=plt.gca()
ax1.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 15)])
for i in sbh_2:
    
        plt.plot(tempo[0:10],i[0:10], 's', ms = '6')
        p1 = np.polyfit(tempo[0:10],i[0:10],1)
        plt.plot(tempo[0:10],np.polyval(p1,tempo[0:10]), lw = '2.5', ls = '-')

          
    
ax1.set_xlim([0.002,0.013])
ax1.set_ylim([-35,-15])
ax1.set_ylabel('ln(IT$^{-3/2}$)', fontsize = 12)
#ax1.set_xlabel('Exposure time (s)', fontsize = 12)
ax1.set_title('0 sec Richardson plots')


ax2 = fig.add_subplot(222)
ax2.plot(vg0s_proper,sbh_proper_2,':s', color = 'black',mfc = 'white', mec = 'black',mew = '1', ms = '9', label = '0 sec ')

ax2.set_ylim([-0.03,0.03])
ax2.set_xlim([-70,70])
ax2.set_title('0 sec Schottky barrier heights')
ax2.set_ylabel('$\phi_{b}$ (eV)', fontsize = 12)
#ax2.set_xlabel('Gate bias (V)', fontsize = 12)
ax3 = fig.add_subplot(221)
colormap = plt.get_cmap('RdBu')
ax3=plt.gca()
ax3.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 15)])

for i in sbh_2:
        
    plt.plot(tempo[10:15],i[10:15], '^', ms = '6')
    p1 = np.polyfit(tempo[10:15],i[10:15],1)
    plt.plot(tempo[10:15],np.polyval(p1,tempo[10:15]), lw = '2.5', ls = '-')
         
    
ax3.set_xlim([0.002,0.013])
ax3.set_ylim([-35,-15])


ax4 = fig.add_subplot(222)

ax4.plot(vg0s_proper,sbh_proper_1,':s', color = 'r',mfc = 'white', mec = 'r',mew = '1', ms = '7', label = '0 sec ')

ax4.set_ylim([-0.15,0.05])
ax4.set_xlim([-70,70])

####################### 4s data

ax5 = fig.add_subplot(223)
colormap = plt.get_cmap('RdBu')
ax5=plt.gca()
ax5.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 15)])

for i in sbh4_2:
        
    plt.plot(tempo4[10:15],i[10:15], '^', ms = '6')
    p1 = np.polyfit(tempo4[10:15],i[10:15],1)
    plt.plot(tempo4[10:15],np.polyval(p1,tempo4[10:15]), lw = '2.5', ls = '-')
         
    
ax5.set_xlim([0.002,0.013])
ax5.set_ylim([-35,-15])


ax6 = fig.add_subplot(224)

ax6.plot(vg0s_proper,sbh4_proper_2,':s', color = 'r',mfc = 'white', mec = 'r',mew = '1', ms = '7', label = '0 sec ')

ax6.set_ylim([-0.15,0.05])
ax6.set_xlim([-70,70])

ax7 = fig.add_subplot(223)
colormap = plt.get_cmap('RdBu')
ax7=plt.gca()
ax7.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 15)])

for i in sbh4_2:
        
    plt.plot(tempo4[0:10],i[0:10], '^', ms = '6')
    p1 = np.polyfit(tempo4[0:10],i[0:10],1)
    plt.plot(tempo4[0:10],np.polyval(p1,tempo4[0:10]), lw = '2.5', ls = '-')
         
    
ax7.set_xlim([0.002,0.013])
ax7.set_ylim([-33,-20])
ax7.set_title('4 sec Richardson plots')
ax7.set_ylabel('ln(IT$^{-3/2}$)', fontsize = 12)
ax7.set_xlabel('T$^{-1}$ (K$^{-1}$)', fontsize = 12)

ax8 = fig.add_subplot(224)

ax8.plot(vg0s_proper,sbh4_proper_1,':s', color = 'black',mfc = 'white', mec = 'black',mew = '1', ms = '7', label = '0 sec ')
ax8.set_title('4 sec Schottky barrier heights')
ax8.set_ylim([-0.07,0.05])
ax8.set_xlim([-70,70])
ax8.set_ylabel('$\phi_{b}$ (eV))', fontsize = 12)
ax8.set_xlabel('Gate bias (V)', fontsize = 12)

plt.tight_layout()
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
fig = plt.figure(figsize=(5,5))
opened_file = open("all_I_0s.txt")
csv_data = csv.reader(opened_file, delimiter="\t")
parsed_data = []

for row in csv_data:
    parsed_data.append(row)
opened_file.close()

data = np.array(parsed_data)
#new_data = data[::8]
ax=plt.gca()
colormap = plt.get_cmap('viridis')
ax.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 120)])
#ax.axvspan(5.5, 6.5, color='orange', alpha=0.5)
for i in range(1,120):
        plt.plot(data[0:17,0],data[0:17,i], '-o',lw = '0.8')
        axes = plt.gca()
            
#axes.set_xlim([0,10])
#axes.set_ylim([0,125])
axes.set_xlabel('1/T (1/K)', fontsize = 25)
axes.set_ylabel('ln(I/T$^{3/2}$)', fontsize = 25)
plt.yticks(fontsize = 15)
plt.xticks(fontsize = 15)
plt.tight_layout()
plt.savefig("0s_schottky_0to-60gate.png", dpi=300)
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-322-b5cae62855bf> in <module>()
#      14 ax.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 120)])
#      15 #ax.axvspan(5.5, 6.5, color='orange', alpha=0.5)
# ---> 16 for i in range(1,120):
#      17         plt.plot(data[0:17,0],data[0:17,i], '-o',lw = '0.8')
#      18         axes = plt.gca()
#
# TypeError: 'list' object is not callable

# %%
fig = plt.figure(figsize=(5,5))



opened_file = open("all_I_0s.txt")
csv_data = csv.reader(opened_file, delimiter="\t")
parsed_data = []

for row in csv_data:
    parsed_data.append(row)
opened_file.close()

data = np.array(parsed_data)
#new_data = data[::8]
ax=plt.gca()
colormap = plt.get_cmap('winter')
ax.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 40)])
#ax.axvspan(5.5, 6.5, color='orange', alpha=0.5)
for i in range(112,224):
        if i % 3 == 0:
            plt.plot(data[0:17,0],data[0:17,i], '-o',lw = '0.8')
            axes = plt.gca()
            
#axes.set_xlim([0,10])
#axes.set_ylim([0,125])
axes.set_xlabel('1/T (1/K)', fontsize = 25)
axes.set_ylabel('ln(I/T$^{3/2}$)', fontsize = 25)
plt.yticks(fontsize = 15)
plt.xticks(fontsize = 15)
plt.tight_layout()
plt.savefig("0s_schottky_0to-60gate.png", dpi=300)

# %%
print(t**5)
print(t**8)
print(t**4.4)

# %%
m = np.linspace(0,100,100)
z = np.linspace(100,200,100)
t = np.linspace(0,100,100)
tt = np.linspace(0, 200, 200)
f = np.linspace(200,0,200)

fig = plt.figure(figsize=(5,5))
sns.set_style('ticks')

ax1 = fig.add_subplot(221)


ax1.plot(f,tt**-1.6,'black', lw = 3, ls = '-', label = '0 sec')

ax1.set_yscale('log')
ax1.set_ylabel('Current', fontsize = 13.5)
#ax1.set_xlabel('Temperature (K)', fontsize = 13.5)
ax1.set_ylim([0,1])
ax1.set_xlim([0,200])
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax1.axvspan(0, 200, color='grey', alpha=0.4)
#ax4.axvspan(100, 200, color='tomato', alpha=0.4)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax1.get_yticklabels(), visible=False)



ax2 = fig.add_subplot(224)

ax2.plot(z,6.31*10**8+t**-1.5,'r', lw = 3)
ax2.plot(m,t**4.4, 'r', lw = 3, label = '8 sec')

#ax2.set_ylabel('Current', fontsize = 13.5)
ax2.set_xlabel('Temperature (K)', fontsize = 10.5)
ax2.set_ylim([0,8*10**8])
ax2.set_xlim([0,200])
#ax2.set_yscale('log')
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=False)
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.axvspan(0, 100, color='dodgerblue', alpha=0.4)
ax2.axvspan(100, 200, color='tomato', alpha=0.4)

ax3 = fig.add_subplot(223)

ax3.plot(z,10**16+t**-3,'g', lw = 3)
ax3.plot(m,t**8, 'g', lw = 3, label = '6 sec')

ax3.set_ylabel('Current', fontsize = 13.5)
ax3.set_xlabel('Temperature (K)', fontsize = 10.5)
ax3.set_ylim([0,0.11*10**17])
ax3.set_xlim([0,200])
#ax3.set_yscale('log')
plt.setp(ax3.get_xticklabels(), visible=False)
plt.setp(ax3.get_yticklabels(), visible=False)
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax3.axvspan(0, 100, color='dodgerblue', alpha=0.4)
ax3.axvspan(100, 200, color='tomato', alpha=0.4)

ax4 = fig.add_subplot(222)

ax4.plot(z,10**10+t**-0.5,'b', lw = 3)
ax4.plot(m,t**5, 'b', lw = 3, label = '4 sec')

#ax4.set_ylabel('Current', fontsize = 13.5)
#ax4.set_xlabel('Temperature (K)', fontsize = 13.5)
ax4.set_ylim([0,0.1255*10**11])
ax4.set_xlim([0,200])
#ax4.set_yscale('log')
plt.setp(ax4.get_xticklabels(), visible=False)
plt.setp(ax4.get_yticklabels(), visible=False)
ax4.xaxis.set_ticks_position('bottom')
ax4.yaxis.set_ticks_position('left')
ax4.axvspan(0, 100, color='dodgerblue', alpha=0.4)
ax4.axvspan(100, 200, color='tomato', alpha=0.4)
ax1.legend(loc = 'upper left', ncol = 1, fontsize=12)
ax2.legend(loc = 'lower right', ncol = 1, fontsize=12)
ax3.legend(loc = 'lower right', ncol = 1, fontsize=12)
ax4.legend(loc = 'lower right', ncol = 1, fontsize=12)

plt.tight_layout()
plt.savefig("regimes.png",bbox_inches='tight', dpi = 300)
plt.show()
