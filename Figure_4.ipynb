# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
import csv
import matplotlib.patches as mpatches
import pylab as pb
import matplotlib.ticker as mtick
from matplotlib import cm
from numpy import linspace
from csv import reader
from matplotlib import pyplot
import matplotlib.colors as colors
import bokeh as bk
import seaborn as sns
import pandas as pd

# %%
gate_bar = []
lowT_bar = []
highT_bar = []
with open('8_sec_barriers.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        gate_bar.append(float(row[0]))
        lowT_bar.append(float(row[1]))
        highT_bar.append(float(row[2]))
        
gate_bar0 = []
lowT_bar0 = []
highT_bar0 = []
with open('0_sec_barriers.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        gate_bar0.append(float(row[0]))
        lowT_bar0.append(float(row[1]))
        highT_bar0.append(float(row[2]))   
        
gate_bar4 = []
lowT_bar4 = []
highT_bar4 = []
with open('4_sec_barriers.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        gate_bar4.append(float(row[0]))
        lowT_bar4.append(float(row[1]))
        highT_bar4.append(float(row[2]))   
        
gate_bar6 = []
lowT_bar6 = []
highT_bar6 = []
with open('6_sec_barriers.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        gate_bar6.append(float(row[0]))
        lowT_bar6.append(float(row[1]))
        highT_bar6.append(float(row[2]))

# %%
temp = []
s_0s = []
xfit_0s = []
yfit_0s  = []
s_4s = []
xfit_4s = []
yfit_4s  = []
s_6s = []
xfit_6s = []
yfit_6s  = []
s_8s = []
xfit_8s = []
yfit_8s  = []
xfit_neg4s = []
yfit_neg4s  = []
xfit_neg6s = []
yfit_neg6s  = []
xfit_neg8s = []
yfit_neg8s  = []
with open('schottky.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        temp.append(float(row[0]))
        s_0s.append(float(row[1]))
        xfit_0s.append(float(row[5]))
        yfit_0s.append(float(row[6]))
        s_4s.append(float(row[2]))
        xfit_4s.append(float(row[7]))
        yfit_4s.append(float(row[8]))
        s_6s.append(float(row[3]))
        xfit_6s.append(float(row[9]))
        yfit_6s.append(float(row[10]))
        s_8s.append(float(row[4]))
        xfit_8s.append(float(row[11]))
        yfit_8s.append(float(row[12]))
        xfit_neg4s.append(float(row[13]))
        yfit_neg4s.append(float(row[14]))
        xfit_neg6s.append(float(row[15]))
        yfit_neg6s.append(float(row[16]))
        xfit_neg8s.append(float(row[17]))
        yfit_neg8s.append(float(row[18]))

# %%
fig = plt.figure(figsize=(8,8))
fig.canvas.draw()

sns.set_style('ticks')

 




ax1 = fig.add_subplot(221)
ax1.plot(temp,s_0s, '-o', ms=10, color = 'black', ls = 'None',lw=2, alpha=0.7, mfc='black', dash_capstyle = 'butt', mew = '1', label = '0 sec'  )
ax1.plot(xfit_0s,yfit_0s, '-', ms=10, color = 'black', lw=2, alpha=0.7, mfc='black', dash_capstyle = 'butt', mew = '1' ) 
ax1.set_title('0 seconds')
#plt.xscale('log')

ax2 = fig.add_subplot(222)
ax2.plot(temp,s_4s, '-^', ms=10, color = 'r', ls = 'None', lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '4 sec' ) 
ax2.plot(xfit_4s,yfit_4s, '-', ms=10, color = 'r',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1') 
ax2.plot(xfit_neg4s,yfit_neg4s, '-', ms=10, color = 'r', lw=2, alpha=0.7, mfc='black', dash_capstyle = 'butt', mew = '1' ) 
ax2.set_title('4 seconds')#
#plt.xscale('log')

ax3 = fig.add_subplot(223)
ax3.plot(temp,s_6s, '-s', ms=10, color = 'g', ls = 'None', lw=2, alpha=0.7, mfc='g', dash_capstyle = 'butt', mew = '1', 
              label = '6 sec' ) 
ax3.plot(xfit_6s,yfit_6s, '-', ms=10, color = 'g',  lw=2, alpha=0.7, mfc='g', dash_capstyle = 'butt', mew = '1' ) 
ax3.plot(xfit_neg6s,yfit_neg6s, '-', ms=10, color = 'g',  lw=2, alpha=0.7, mfc='g', dash_capstyle = 'butt', mew = '1' ) 
ax3.set_title('6 seconds')
#plt.xscale('log')

ax4 = fig.add_subplot(224)
ax4.plot(temp,s_8s, '-d', ms=10, color = 'b', ls = 'None', lw=2, alpha=0.7, mfc='b', dash_capstyle = 'butt', mew = '1', 
              label = '8 sec' ) 
ax4.plot(xfit_neg8s,yfit_neg8s, '-', ms=10, color = 'b',  lw=2, alpha=0.7, mfc='g', dash_capstyle = 'butt', mew = '1' ) 
ax4.plot(xfit_8s,yfit_8s, '-', ms=10, color = 'b',  lw=2, alpha=0.7, mfc='b', dash_capstyle = 'butt', mew = '1' ) 
ax4.set_title('8 seconds')
#plt.xscale('log')
ax1.set_ylabel('ln(I/T$^{3/2}$)', fontsize = 13.5)
ax3.set_xlabel('T$^{-1}$ (K$^{-1}$)', fontsize = 13.5)
ax3.set_ylabel('ln(I/T$^{3/2}$)', fontsize = 13.5)
ax4.set_xlabel('T$^{-1}$ (K$^{-1}$)', fontsize = 13.5)


plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=True)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=True)
plt.setp(ax4.get_yticklabels(), visible=True)
plt.setp(ax4.get_xticklabels(), visible=True)

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax4.xaxis.set_ticks_position('bottom')
ax4.yaxis.set_ticks_position('left')



#ax1.set_ylim([0.0000000001,0.00001])
#ax2.set_ylim([0.0000000001,0.00001])
#ax3.set_ylim([0.000000005,0.00001])
#ax4.set_ylim([0.0000000001,0.0001])
#ax1.set_xlim([0.003,0.014])
#ax2.set_xlim([0.003,0.014])
#ax3.set_xlim([0.003,0.014])
#ax4.set_xlim([0.003,0.014])

#major_ticks_1 = np.arange(0.004, 0.012, 0.002)   
#ax4.set_xticks(major_ticks_1) 
#ax2.set_xticks(major_ticks_1)
#ax1.legend(loc = 'upper right', ncol = 1, fontsize=12)
#ax2.legend(loc = 'upper right', ncol = 1, fontsize=12)
#ax3.legend(loc = 'upper right', ncol = 1, fontsize=12)
#ax4.legend(loc = 'upper right', ncol = 1, fontsize=12)
plt.savefig("Fig_4_tot.png",bbox_inches='tight', dpi = 300)


plt.show()

# %%
fig = plt.figure(figsize=(12,12))
fig.canvas.draw()
sns.set_style('ticks')

min, max = (-60, 60)
step = 5
mymap = mpl.colors.LinearSegmentedColormap.from_list('mycolors',['blue','red'])
Z = [[0,0],[0,0]]
levels = range(min,max+step,step)
CS3 = plt.contourf(Z, levels, cmap='viridis', fontsize = 40)
plt.clf()  
cbaxes = fig.add_axes([0.275, 1.051, 0.5, 0.025]) 
plt.colorbar(CS3, cax = cbaxes, orientation ='horizontal') 

ax1 = fig.add_subplot(441)
opened_file = open("Richardson_0_sec.txt")
csv_data = csv.reader(opened_file, delimiter="\t")
parsed_data = []

for row in csv_data:
    parsed_data.append(row)
opened_file.close()

data = np.array(parsed_data)
#new_data = data[::3]
ax=plt.gca()
colormap = plt.get_cmap('viridis')
ax.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 25)])
#ax.axvspan(5.5, 6.5, color='orange', alpha=0.5)
for i in range(1,25):
        plt.plot(data[0:25,0],data[0:25,i],'o', ms = 5)
        axes = plt.gca()
          
    
#ax1.set_xlim([0.002,0.013])
ax1.set_ylim([-33,-17])
ax1.set_ylabel('ln[I/T$^{3/2}$]', fontsize = 16)
ax1.set_xlabel('1000/T (K$^{-1}$)', fontsize = 12)
ax1.set_title('0 seconds')

ax2 = fig.add_subplot(442)
opened_file = open("Richardson_4_sec.txt")
csv_data = csv.reader(opened_file, delimiter="\t")
parsed_data = []

for row in csv_data:
    parsed_data.append(row)
opened_file.close()

data4 = np.array(parsed_data)
new_data4 = data4[:,0::6]
ax=plt.gca()
colormap = plt.get_cmap('viridis')
ax.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 40)])
#ax.axvspan(5.5, 6.5, color='orange', alpha=0.5)
for i in range(1,40):
        plt.plot(new_data4[0:40,0],new_data4[0:40,i],'o', ms = 5)
        axes = plt.gca()
          
    
#ax1.set_xlim([0.002,0.013])
ax2.set_ylim([-33,-22])
#ax1.set_ylabel('ln(I/T$^{3/2}$)', fontsize = 12)
ax2.set_xlabel('1000/T (K$^{-1}$)', fontsize = 12)
ax2.set_title('4 seconds')

ax3 = fig.add_subplot(443)
opened_file = open("Richardson_6_sec.txt")
csv_data = csv.reader(opened_file, delimiter="\t")
parsed_data = []

for row in csv_data:
    parsed_data.append(row)
opened_file.close()

data6 = np.array(parsed_data)
new_data6 = data6[:,0::6]
ax=plt.gca()
colormap = plt.get_cmap('viridis')
ax.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 40)])
#ax.axvspan(5.5, 6.5, color='orange', alpha=0.5)
for i in range(1,40):
        plt.plot(new_data6[0:40,0],new_data6[0:40,i],'o', ms = 5)
        axes = plt.gca()
          
    
#ax1.set_xlim([0.002,0.013])
ax3.set_ylim([-38,-24])
#ax1.set_ylabel('ln(I/T$^{3/2}$)', fontsize = 12)
ax3.set_xlabel('1000/T (K$^{-1}$)', fontsize = 12)
ax3.set_title('6 seconds')

ax4 = fig.add_subplot(444)
opened_file = open("Richardson_8_sec.txt")
csv_data = csv.reader(opened_file, delimiter="\t")
parsed_data = []

for row in csv_data:
    parsed_data.append(row)
opened_file.close()

data8 = np.array(parsed_data)
new_data8 = data8[:,0::6]
ax=plt.gca()
colormap = plt.get_cmap('viridis')
ax.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 40)])
#ax.axvspan(5.5, 6.5, color='orange', alpha=0.5)
for i in range(1,40):
        plt.plot(new_data8[0:40,0],new_data8[0:40,i],'o', ms = 5)
        axes = plt.gca()
          
    
#ax1.set_xlim([0.002,0.013])
#ax3.set_ylim([-38,-24])
#ax1.set_ylabel('ln(I/T$^{3/2}$)', fontsize = 12)
ax4.set_xlabel('1000/T (K$^{-1}$)', fontsize = 12)
ax4.set_title('8 seconds')

ax5 = fig.add_subplot(445)
ax5.plot(gate_bar0,lowT_bar0, 'o', ms=6, color = 'blue',lw=2, alpha=0.7, mfc='blue', dash_capstyle = 'butt', mew = '1',
         label = '233-83K'  )
ax5.plot(gate_bar0,highT_bar0, 'o', ms=6, color = 'red', lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt',
         mew = '1', label = '293-233K' ) 
ax5.set_xlabel('Gate bias (V)', fontsize = 13.5)
ax5.set_ylabel('Effective $\phi_{B}$', fontsize = 15)
#ax5.set_ylim([-1,1.6])
ax5.set_xlim([-65,65])
ax5.legend(loc = 'upper right',labelspacing=0.01, fontsize = 8)

ax6 = fig.add_subplot(446)
ax6.plot(gate_bar4,lowT_bar4, 'o', ms=6, color = 'blue',lw=2, alpha=0.7, mfc='blue', dash_capstyle = 'butt', mew = '1',
         label = '173-83K'  )
ax6.plot(gate_bar4,highT_bar4, 'o', ms=6, color = 'red', lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt',
         mew = '1', label = '293-173K' ) 
ax6.set_xlabel('Gate bias (V)', fontsize = 13.5)
#ax5.set_ylabel('Effective $\phi_{B}$', fontsize = 15)
ax6.set_ylim([-0.7,0.9])
ax6.set_xlim([-65,65])
ax6.legend(loc = 'lower left',labelspacing=0.01, fontsize = 8)

ax7 = fig.add_subplot(447)
ax7.plot(gate_bar6,lowT_bar6, 'o', ms=6, color = 'blue',lw=2, alpha=0.7, mfc='blue', dash_capstyle = 'butt', mew = '1',
         label = '173-83K'  )
ax7.plot(gate_bar6,highT_bar6, 'o', ms=6, color = 'red', lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1',
        label = '293-173K') 
ax7.set_xlabel('Gate bias (V)', fontsize = 13.5)
#ax7.set_ylim([-1,1.6])
ax7.set_xlim([-65,65])
ax7.legend(loc = 'lower left',labelspacing=0.01, fontsize = 8)    

ax8 = fig.add_subplot(448)
ax8.plot(gate_bar,lowT_bar, 'o', ms=6, color = 'blue',lw=2, alpha=0.7, mfc='blue', dash_capstyle = 'butt', mew = '1',
         label = '182-83K'  )
ax8.plot(gate_bar,highT_bar, 'o', ms=6, color = 'red', lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1',
        label = '293-182K') 
ax8.set_xlabel('Gate bias (V)', fontsize = 13.5)
ax8.set_ylim([-1,1.6])
ax8.set_xlim([-65,65])
ax8.legend(loc = 'lower left',labelspacing=0.01, fontsize = 8)          
    


plt.tight_layout()
plt.savefig("Richardson_Schottkys.png",bbox_inches='tight', dpi=300)
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
