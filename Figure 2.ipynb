# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
import csv
import matplotlib.patches as mpatches
import pylab as pb
import matplotlib.ticker as mtick
from matplotlib import cm
from numpy import linspace
from csv import reader
from matplotlib import pyplot
import matplotlib.colors as colors
import bokeh as bk
import seaborn as sns
import pandas as pd

# %%
x8 = []
y8 = []
with open('8sec_lnW.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x8.append(float(row[0]))
        y8.append(float(row[1]))

x_low_T_8 = []
y_low_T_8 = []
with open('8_sec_lowT_fit.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x_low_T_8.append(float(row[0]))
        y_low_T_8.append(float(row[1]))
        
x_high_T_8 = []
y_high_T_8 = []
with open('8_sec_highT_fit.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x_high_T_8.append(float(row[0]))
        y_high_T_8.append(float(row[1]))
        
x6 = []
y6 = []
with open('6sec_lnW.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x6.append(float(row[0]))
        y6.append(float(row[1]))

x_low_T_6 = []
y_low_T_6 = []
with open('6_sec_lowT_fit.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x_low_T_6.append(float(row[0]))
        y_low_T_6.append(float(row[1]))  
        
x_high_T_6 = []
y_high_T_6 = []
with open('6_sec_highT_fit.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x_high_T_6.append(float(row[0]))
        y_high_T_6.append(float(row[1]))
        
x4 = []
y4 = []
with open('4sec_lnW.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x4.append(float(row[0]))
        y4.append(float(row[1]))

x_low_T_4 = []
y_low_T_4 = []
with open('4_sec_lowT_fit.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x_low_T_4.append(float(row[0]))
        y_low_T_4.append(float(row[1]))
        
x_high_T_4 = []
y_high_T_4 = []
with open('4_sec_highT_fit.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x_high_T_4.append(float(row[0]))
        y_high_T_4.append(float(row[1]))

        
x0 = []
y0 = []
with open('0sec_lnW.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x0.append(float(row[0]))
        y0.append(float(row[1]))

x_all_T_0 = []
y_all_T_0 = []
with open('0_sec_allT_fit.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x_all_T_0.append(float(row[0]))
        y_all_T_0.append(float(row[1]))

# %%
fig = plt.figure(figsize=(6,6))
fig.canvas.draw()
sns.set_style('ticks')

ax1 = fig.add_subplot(221)
ax1.plot(x0,y0, 'o', ms=8, color = 'blue',lw=2, mfc='skyblue', dash_capstyle = 'butt', mew = '1' )
ax1.plot(x_all_T_0,y_all_T_0, '-', color = 'red', lw=2.5, alpha=0.7) 
#ax1.set_xlabel('ln T', fontsize = 13.5)
ax1.set_ylabel('ln W', fontsize = 13.5)
ax1.set_ylim([2,2.8])
ax1.set_xlim([4,6])
ax1.set_title('0 seconds \n')
ax1.legend(loc = 'lower left',labelspacing=0.01, fontsize = 8) 

ax2 = fig.add_subplot(222)
ax2.plot(x4,y4, 'o', ms=8, color = 'blue',lw=2,  mfc='skyblue', dash_capstyle = 'butt', mew = '1' )
ax2.plot(x_low_T_4,y_low_T_4, '-', color = 'red', lw=2.5, alpha=1) 
ax2.plot(x_high_T_4,y_high_T_4, '-', color = 'purple', lw=2.5, alpha=1) 
#ax2.set_xlabel('ln T', fontsize = 13.5)
#ax2.set_ylim([3,4])
ax2.set_xlim([4,6])
ax2.set_title('4 seconds \n')
ax2.legend(loc = 'lower left',labelspacing=0.01, fontsize = 8) 

ax3 = fig.add_subplot(223)
ax3.plot(x6,y6, 'o', ms=8, color = 'blue',lw=2, mfc='skyblue', dash_capstyle = 'butt', mew = '1')
ax3.plot(x_low_T_6,y_low_T_6, '-', color = 'red', lw=2.5, alpha=1) 
ax3.plot(x_high_T_6,y_high_T_6, '-', color = 'purple', lw=2.5, alpha=1) 
ax3.set_xlabel('ln T', fontsize = 13.5)
ax3.set_ylabel('ln W', fontsize = 13.5)
ax3.set_ylim([3,4.5])
ax3.set_xlim([4,6])
ax3.set_title('6 seconds \n')
ax3.legend(loc = 'lower left',labelspacing=0.01, fontsize = 8) 

ax4 = fig.add_subplot(224)
ax4.plot(x8,y8, 'o', ms=8, color = 'blue',lw=2,  mfc='skyblue', dash_capstyle = 'butt', mew = '1', mec = 'black')
ax4.plot(x_low_T_8,y_low_T_8, '-', color = 'red', lw=2.5, alpha=1) 
ax4.plot(x_high_T_8,y_high_T_8, '-', color = 'purple', lw=2.5, alpha=1) 
ax4.set_xlabel('ln T', fontsize = 13.5)
ax4.set_ylim([3.2,4.6])
#ax4.set_xlim([4.2,6])
ax4.set_title('8 seconds \n')
ax4.legend(loc = 'lower left',labelspacing=0.01, fontsize = 8) 
    
plt.tight_layout()
plt.savefig("Regime_fits.png",bbox_inches='tight', dpi=300)
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
