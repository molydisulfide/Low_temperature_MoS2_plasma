# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
import csv
import matplotlib.patches as mpatches
import pylab as pb
import matplotlib.ticker as mtick
from matplotlib import cm
from numpy import linspace
from csv import reader
from matplotlib import pyplot
import matplotlib.colors as colors
import bokeh as bk
import seaborn as sns
import pandas as pd

# %%
xvth = []
vth_0s = []
vth_0s_err = []
vth_4s = []
vth_4s_err = []
vth_6s = []
vth_6s_err = []
vth_8s = []
vth_8s_err = []
with open('V_ths.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        xvth.append(float(row[0]))
        vth_0s.append(float(row[1]))
        vth_0s_err.append(float(row[2]))
        vth_4s.append(float(row[3]))
        vth_4s_err.append(float(row[4]))
        vth_6s.append(float(row[5]))
        vth_6s_err.append(float(row[6]))
        vth_8s.append(float(row[7]))
        vth_8s_err.append(float(row[8]))

# %%
fig = plt.figure(figsize=(2,4))
sns.set_style('ticks')
fig.canvas.draw()

ax1 = fig.add_subplot(111)
ax1.plot(xvth,vth_0s, 'o', ms=7, color = 'g', lw=2, alpha=0.7, mfc='g', dash_capstyle = 'butt', mew = '1', label = '0 sec' ) 
ax1.plot(xvth,vth_4s, 's', ms=7, color = 'r',  lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '4 sec' ) 
ax1.plot(xvth,vth_6s, '^', ms=7, color = 'b',  lw=2, alpha=0.7, mfc='b', dash_capstyle = 'butt', mew = '1', 
              label = '6 sec' ) 
ax1.plot(xvth,vth_8s, 'v', ms=7, color = 'black', lw=2, alpha=0.7, mfc='black', dash_capstyle = 'butt', mew = '1', label = '8 sec' ) 
 
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax1.set_ylabel('Threshold voltage (V)', fontsize = 12)
ax1.set_xlabel('Temperature (K)', fontsize = 12)
ax1.legend(loc= 'upper right',ncol = 1, fontsize = 10)
plt.savefig("Fig_1f.png",bbox_inches='tight', dpi = 300)


plt.show()

# %%
fig = plt.figure(figsize=(4,4))
fig.canvas.draw()
sns.set_style('ticks')


 
min, max = (83, 293)
step = 10
mymap = mpl.colors.LinearSegmentedColormap.from_list('mycolors',['blue','red'])
Z = [[0,0],[0,0]]
levels = range(min,max+step,step)

CS3 = plt.contourf(Z, levels, cmap='coolwarm', fontsize = 40)

plt.clf()  
cbaxes = fig.add_axes([1, 0.1, 0.03, 0.8]) 
cb = plt.colorbar(CS3, cax = cbaxes) 
# using the colorbar info I got from contourf 


opened_file = open("gates.txt")
csv_data = csv.reader(opened_file, delimiter="\t")
parsed_data = []
for row in csv_data:
    parsed_data.append(row)
opened_file.close()
data = np.array(parsed_data)

opened_file4 = open("gates_4s.txt")
csv_data4 = csv.reader(opened_file4, delimiter="\t")
parsed_data4 = []
for row in csv_data4:
    parsed_data4.append(row)
opened_file4.close()
data4 = np.array(parsed_data4)

opened_file6 = open("gates_6s.txt")
csv_data6 = csv.reader(opened_file6, delimiter="\t")
parsed_data6 = []
for row in csv_data6:
    parsed_data6.append(row)
opened_file6.close()
data6 = np.array(parsed_data6)

opened_file8 = open("gates_8s.txt")
csv_data8 = csv.reader(opened_file8, delimiter="\t")
parsed_data8 = []


ax1 = fig.add_subplot(221)


colormap = plt.get_cmap('coolwarm')
ax1.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 16)])

for i in range(1,16):
        plt.plot(data[0:241,0],data[0:241,i], lw = 2)
        #ax1 = plt.gca()

ax1.set_ylim([0.00000000005,0.00003])
#ax1.set_xlabel('Gate bias (V)', fontsize = 15)
ax1.set_ylabel('I$_{DS}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
ax1.set_yscale('log')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax1.set_title('0 seconds')

ax2 = fig.add_subplot(222)


colormap = plt.get_cmap('coolwarm')
ax2.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 17)])

for i in range(1,17):
        plt.plot(data4[0:241,0],data4[0:241,i], lw = 2)
        #ax2 = plt.gca()

ax2.set_ylim([0.00000000003,0.000001])
#ax2.set_xlabel('Gate bias (V)', fontsize = 15)
#ax2.set_ylabel('I$_{DS}$ (A)', fontsize = 15)
plt.ticklabel_format(style='sci', axis='y')
ax2.set_yscale('log')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('4 seconds')



ax3 = fig.add_subplot(223)


colormap = plt.get_cmap('coolwarm')
ax3.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 17)])

for i in range(1,17):
        plt.plot(data6[0:241,0],data6[0:241,i], lw = 2)
        #ax3 = plt.gca()

ax3.set_ylim([0.000000000003,0.0000001])
ax3.set_xlabel('Gate bias (V)', fontsize = 12)
ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
ax3.set_yscale('log')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax3.set_title('6 seconds')

ax4 = fig.add_subplot(224)
for row in csv_data8:
    parsed_data8.append(row)
opened_file8.close()

data8 = np.array(parsed_data8)

colormap = plt.get_cmap('coolwarm')
ax4.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 17)])

for i in range(1,17):
        plt.plot(data8[0:241,0],data8[0:241,i], lw = 2)
        #ax4 = plt.gca()

ax4.set_ylim([0.000000000003,0.0000001])
ax4.set_xlabel('Gate bias (V)', fontsize = 12)
#ax4.set_ylabel('I$_{DS}$ (A)', fontsize = 15)
plt.ticklabel_format(style='sci', axis='y')
ax4.set_yscale('log')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax4.set_title('8 seconds')

#ax1.set_ylabel('Conductance (S)', fontsize = 12)
#ax3.set_xlabel('Exposure time (s)', fontsize = 12)
#ax3.set_ylabel('Conductance (S)', fontsize = 12)
#ax4.set_xlabel('Exposure time (s)', fontsize = 12)

plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=True)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=False)
plt.setp(ax4.get_yticklabels(), visible=False)
plt.setp(ax4.get_xticklabels(), visible=True)

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax4.xaxis.set_ticks_position('bottom')
ax4.yaxis.set_ticks_position('left')




major_ticks_1 = np.arange(-60, 61, 60)   
ax4.set_xticks(major_ticks_1) 
ax2.set_xticks(major_ticks_1)
ax3.set_xticks(major_ticks_1) 
ax1.set_xticks(major_ticks_1)
#ax1.legend(loc = 'upper right', ncol = 1, fontsize=12)
#ax2.legend(loc = 'upper right', ncol = 1, fontsize=12)
#x3.legend(loc = 'upper right', ncol = 1, fontsize=12)
#ax4.legend(loc = 'upper right', ncol = 1, fontsize=12)
plt.savefig("Fig_1_all.png",bbox_inches='tight', dpi = 300)


plt.show()
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
fig = plt.figure(figsize=(6,3))
fig.canvas.draw()
sns.set_style('ticks')


 
min, max = (83, 293)
step = 10
mymap = mpl.colors.LinearSegmentedColormap.from_list('mycolors',['blue','red'])
Z = [[0,0],[0,0]]
levels = range(min,max+step,step)

CS3 = plt.contourf(Z, levels, cmap='coolwarm', fontsize = 40)

plt.clf()  
cbaxes = fig.add_axes([1, 0.1, 0.03, 0.8]) 
cb = plt.colorbar(CS3, cax = cbaxes) 
# using the colorbar info I got from contourf 


opened_fileiv = open("all_IVs_0s.txt")
csv_dataiv = csv.reader(opened_fileiv, delimiter="\t")
parsed_dataiv = []
for row in csv_dataiv:
    parsed_dataiv.append(row)
opened_fileiv.close()
dataiv = np.array(parsed_dataiv)

opened_fileiv4 = open("all_IVs_4s.txt")
csv_dataiv4 = csv.reader(opened_fileiv4, delimiter="\t")
parsed_dataiv4 = []
for row in csv_dataiv4:
    parsed_dataiv4.append(row)
opened_fileiv4.close()
dataiv4 = np.array(parsed_dataiv4)





ax1 = fig.add_subplot(121)
colormap = plt.get_cmap('coolwarm')
ax1.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 17)])
for i in range(1,17):
        plt.plot(dataiv[0:201,0],dataiv[0:201,i], lw = 2)
        
ax1.set_ylim([-0.0000005,0.0000005])
ax1.set_xlabel('Drain-source bias (V)', fontsize = 12)
ax1.set_ylabel('I$_{DS}$ (10 $\mu$A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')

plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax1.set_title('0 seconds')



ax2 = fig.add_subplot(122)
colormap = plt.get_cmap('coolwarm')
ax2.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 17)])
for i in range(1,17):
        plt.plot(dataiv4[0:201,0],dataiv4[0:201,i], lw = 2)
        
ax2.set_ylim([-0.000000003,0.000000003])
ax2.set_xlabel('Drain-source bias (V)', fontsize = 12)
ax2.set_ylabel('I$_{DS}$ (nA)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')

plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('4 seconds')







#ax1.set_ylabel('Conductance (S)', fontsize = 12)
#ax3.set_xlabel('Exposure time (s)', fontsize = 12)
#ax3.set_ylabel('Conductance (S)', fontsize = 12)
#ax4.set_xlabel('Exposure time (s)', fontsize = 12)

plt.setp(ax1.get_xticklabels(), visible=True)
plt.setp(ax1.get_yticklabels(), visible=True)
plt.setp(ax2.get_xticklabels(), visible=True)
plt.setp(ax2.get_yticklabels(), visible=True)

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')



plt.tight_layout()

major_ticks_2 = np.arange(-1, 1.1, 0.5)   

ax2.set_xticks(major_ticks_2)

ax1.set_xticks(major_ticks_2)
#ax1.legend(loc = 'upper right', ncol = 1, fontsize=12)
#ax2.legend(loc = 'upper right', ncol = 1, fontsize=12)
#x3.legend(loc = 'upper right', ncol = 1, fontsize=12)
#ax4.legend(loc = 'upper right', ncol = 1, fontsize=12)
plt.savefig("Fig_1_IVs.png",bbox_inches='tight', dpi = 300)


plt.show()
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
