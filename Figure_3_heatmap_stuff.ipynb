# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
import csv
import matplotlib.patches as mpatches
import pylab as pb
import matplotlib.ticker as mtick
from matplotlib import cm
from numpy import linspace
from csv import reader
from matplotlib import pyplot
import matplotlib.colors as colors
import bokeh as bk
import seaborn as sns
import pandas as pd

# %%
time = []
n_2D_11e11_250K = []
n_2D_11e11_125K  = []
n_2D_11e11_83K  = []
n_2D_73e11_250K = []
n_2D_73e11_125K  = []
n_2D_73e11_93K  = []
n_2D_11e12_250K = []
n_2D_11e12_125K  = []
n_2D_11e12_114K  = []
n_2D_15e12_250K = []
n_2D_15e12_125K  = []
n_2D_15e12_102K  = []
with open('n_2Ds.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        n_2D_11e11_250K.append(float(row[0]))
        n_2D_11e11_125K.append(float(row[1]))
        n_2D_11e11_83K.append(float(row[2]))
        n_2D_73e11_250K.append(float(row[3]))
        n_2D_73e11_125K.append(float(row[4]))
        n_2D_73e11_93K.append(float(row[5]))
        n_2D_11e12_250K.append(float(row[6]))
        n_2D_11e12_125K.append(float(row[7]))
        n_2D_11e12_114K.append(float(row[8]))
        n_2D_15e12_250K.append(float(row[9]))
        n_2D_15e12_125K.append(float(row[10]))
        n_2D_15e12_102K.append(float(row[11]))

# %%
import matplotlib.pyplot as plt
import numpy as np

#here's our data to plot, all normal Python lists
time = [8, 6, 4, 0]
n_2D = [1.5e11, 7.3e11, 1.1e12, 1.5e12]

conductance = [
[2.64715E-6,1.30973E-7,1.71E-9,1.4843E-9],
[4.03157E-6,2.1743E-7,5.732E-9,3.6035E-9],
[5.09757E-6,2.90808E-7,1.0507E-8,5.8634E-9],
[6.41771E-6,3.90842E-7,1.8169E-8,1.77E-9]
]

#setup the 2D grid with Numpy
#time, n_2D = np.meshgrid(time, n_2D)

#convert intensity (list of lists) to a numpy array for plotting
conductance = np.array(conductance)

plt.contourf(time, n_2D, conductance,500, cmap='coolwarm')
plt.colorbar() #need a colorbar to show the intensity scale
plt.show() #boom

# %%
fig, ax = plt.subplots()
s = 121
ax.scatter(time, n_2D, color='r', s=2*s, marker='^', alpha=.4)

# %%
plt.figure(1, figsize=(8, 8))
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
rect_scatter = [left, bottom, width, height]
axScatter = plt.axes(rect_scatter)
s = [20*4**n for n in range(len(n_2D))]

color = [str(item/255.) for item in n_2D]
# the scatter plot:
axScatter.scatter(time, n_2D,s = s, c = color)

# %%
fig = plt.figure(figsize=(8,8))
fig.canvas.draw()



ax1 = fig.add_subplot(221)
ax1.plot(time,n_2D_11e11_250K, '-o', ms=10, color = 'black', ls = 'none', lw=2, alpha=0.7, mfc='black', dash_capstyle = 'butt', mew = '1', 
              label = '250 K' ) 
ax1.plot(time,n_2D_11e11_125K, '-^', ms=10, color = 'r', ls = 'none', lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '125 K' ) 
ax1.plot(time,n_2D_11e11_83K, '-s', ms=10, color = 'g', ls = 'none', lw=2, alpha=0.7, mfc='g', dash_capstyle = 'butt', mew = '1', 
              label = '83 K' ) 

ax1.set_title('n$_{2D}$ = $1.5 \cdot 10^{11}$ cm$^{-2}$')

ax2 = fig.add_subplot(222)
ax2.plot(time,n_2D_73e11_250K , '-o', ms=10, color = 'black', ls = 'none', lw=2, alpha=0.7, mfc='black', dash_capstyle = 'butt', mew = '1', 
              label = '250 K' ) 
ax2.plot(time,n_2D_73e11_125K , '-^', ms=10, color = 'r', ls = 'none', lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '125 K' ) 
ax2.plot(time,n_2D_73e11_93K , '-s', ms=10, color = 'g', ls = 'none', lw=2, alpha=0.7, mfc='g', dash_capstyle = 'butt', mew = '1', 
              label = '93 K' ) 

ax2.set_title('n$_{2D}$ = $7.3 \cdot 10^{11}$ cm$^{-2}$')

ax3 = fig.add_subplot(223)
ax3.plot(time,n_2D_11e12_250K , '-o', ms=10, color = 'black', ls = 'none', lw=2, alpha=0.7, mfc='black', dash_capstyle = 'butt', mew = '1', 
              label = '250 K' ) 
ax3.plot(time,n_2D_11e12_125K , '-^', ms=10, color = 'r', ls = 'none', lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '125 K' ) 
ax3.plot(time,n_2D_11e12_114K , '-s', ms=10, color = 'g', ls = 'none', lw=2, alpha=0.7, mfc='g', dash_capstyle = 'butt', mew = '1', 
              label = '114 K' ) 


ax3.set_title('n$_{2D}$ = $1.1 \cdot 10^{12}$ cm$^{-2}$')

ax4 = fig.add_subplot(224)
ax4.plot(time,n_2D_15e12_250K , '-o', ms=10, color = 'black', ls = 'none', lw=2, alpha=0.7, mfc='black', dash_capstyle = 'butt', mew = '1', 
              label = '250 K' ) 
ax4.plot(time,n_2D_15e12_125K , '-^', ms=10, color = 'r', ls = 'none', lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '1', 
              label = '125 K' ) 
ax4.plot(time,n_2D_15e12_102K , '-s', ms=10, color = 'g', ls = 'none', lw=2, alpha=0.7, mfc='g', dash_capstyle = 'butt', mew = '1', 
              label = '102 K' ) 

ax4.set_title('n$_{2D}$ = $1.5 \cdot 10^{12}$ cm$^{-2}$')

ax1.set_ylabel('Conductance ($\mu$S)', fontsize = 12)
ax3.set_xlabel('Exposure time (s))', fontsize = 12)
ax3.set_ylabel('Conductance (nS)', fontsize = 12)
ax4.set_xlabel('Exposure time (s))', fontsize = 12)

plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=True)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=True)
plt.setp(ax4.get_yticklabels(), visible=True)
plt.setp(ax4.get_xticklabels(), visible=True)

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax4.xaxis.set_ticks_position('bottom')
ax4.yaxis.set_ticks_position('left')

plt.ticklabel_format(style='sci', axis='y')
ax1.set_yscale('log')
ax2.set_yscale('log')
ax3.set_yscale('log')
ax4.set_yscale('log')

#ax1.set_ylim([1.5,10])
#ax2.set_ylim([0.01,1])
#ax3.set_ylim([0.8,27])
#ax4.set_ylim([0.5,10])

#major_ticks_1 = np.arange(0.004, 0.012, 0.002)   
#ax4.set_xticks(major_ticks_1) 
#ax2.set_xticks(major_ticks_1)

ax2.legend(bbox_to_anchor=(1.6, 0.2), ncol = 1, fontsize=12)

plt.savefig("Fig_3.png",bbox_inches='tight', dpi = 300)


plt.show()
